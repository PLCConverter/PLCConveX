# %%
import xml.etree.ElementTree as ET

def find_contact_with_edge(xml_file):
    try:
        # Parse the XML file
        tree = ET.parse(xml_file)
        root = tree.getroot()
        
        # Define the namespace
        namespace = "http://www.plcopen.org/xml/tc6_0200"
        contact_tag = f"{{{namespace}}}contact"  # Full tag with namespace
        print(contact_tag)
        # Keep track if we found any matches
        found = False
        
        # Iterate through all elements in the entire XML tree
        for elem in root.iter():
            # Check if the element is a <contact> with the namespace
            if elem.tag == contact_tag:
                # Get the 'edge' attribute if it exists
                print(elem.attrib)
                edge_value = elem.get("edge")
                # Check if edge exists and is not "none"
                if edge_value is not None and edge_value.lower() != "none":
                    # Get the line number from the element's source location
                    line_number = elem.sourceline
                    print(f"Found <contact> with edge='{edge_value}' at line {line_number}")
                    found = True
        
        if not found:
            print("No <contact> elements with edge attribute not 'none' were found.")
            
    except FileNotFoundError:
        print(f"Error: The file '{xml_file}' was not found.")
    except ET.ParseError:
        print("Error: The XML file is not well-formed or invalid.")
    except Exception as e:
        print(f"An unexpected error occurred: {str(e)}")

xml_file = "D:/SoftWares/OpenPLC/Ino_simple/LD_HARD_PLAIN.xml"
find_contact_with_edge(xml_file)
# Out:
# {http://www.plcopen.org/xml/tc6_0200}contact
# {http://www.plcopen.org/xml/tc6_0200}project
# {http://www.plcopen.org/xml/tc6_0200}fileHeader
# {http://www.plcopen.org/xml/tc6_0200}contentHeader
# {http://www.plcopen.org/xml/tc6_0200}coordinateInfo
# {http://www.plcopen.org/xml/tc6_0200}fbd
# {http://www.plcopen.org/xml/tc6_0200}scaling
# {http://www.plcopen.org/xml/tc6_0200}ld
# {http://www.plcopen.org/xml/tc6_0200}scaling
# {http://www.plcopen.org/xml/tc6_0200}sfc
# {http://www.plcopen.org/xml/tc6_0200}scaling
# {http://www.plcopen.org/xml/tc6_0200}addData
# {http://www.plcopen.org/xml/tc6_0200}data
# {http://www.plcopen.org/xml/tc6_0200}ProjectInformation
# {http://www.plcopen.org/xml/tc6_0200}types
# {http://www.plcopen.org/xml/tc6_0200}dataTypes
# {http://www.plcopen.org/xml/tc6_0200}pous
# {http://www.plcopen.org/xml/tc6_0200}instances
# {http://www.plcopen.org/xml/tc6_0200}configurations
# {http://www.plcopen.org/xml/tc6_0200}addData
# {http://www.plcopen.org/xml/tc6_0200}data
# {http://www.plcopen.org/xml/tc6_0200}resource
# {http://www.plcopen.org/xml/tc6_0200}globalVars
# {http://www.plcopen.org/xml/tc6_0200}variable
# {http://www.plcopen.org/xml/tc6_0200}type
# {http://www.plcopen.org/xml/tc6_0200}derived
# {http://www.plcopen.org/xml/tc6_0200}variable
# {http://www.plcopen.org/xml/tc6_0200}type
# {http://www.plcopen.org/xml/tc6_0200}derived
# {http://www.plcopen.org/xml/tc6_0200}variable
# {http://www.plcopen.org/xml/tc6_0200}type
# {http://www.plcopen.org/xml/tc6_0200}derived
# {http://www.plcopen.org/xml/tc6_0200}variable
# {http://www.plcopen.org/xml/tc6_0200}type
# {http://www.plcopen.org/xml/tc6_0200}derived
# {http://www.plcopen.org/xml/tc6_0200}variable
# {http://www.plcopen.org/xml/tc6_0200}type
# {http://www.plcopen.org/xml/tc6_0200}derived
# {http://www.plcopen.org/xml/tc6_0200}variable
# {http://www.plcopen.org/xml/tc6_0200}type
# {http://www.plcopen.org/xml/tc6_0200}derived
# {http://www.plcopen.org/xml/tc6_0200}globalVars
# {http://www.plcopen.org/xml/tc6_0200}variable
# {http://www.plcopen.org/xml/tc6_0200}type
# {http://www.plcopen.org/xml/tc6_0200}BOOL
# {http://www.plcopen.org/xml/tc6_0200}variable
# {http://www.plcopen.org/xml/tc6_0200}type
# {http://www.plcopen.org/xml/tc6_0200}BOOL
# {http://www.plcopen.org/xml/tc6_0200}variable
# {http://www.plcopen.org/xml/tc6_0200}type
# {http://www.plcopen.org/xml/tc6_0200}BOOL
# {http://www.plcopen.org/xml/tc6_0200}variable
# {http://www.plcopen.org/xml/tc6_0200}type
# {http://www.plcopen.org/xml/tc6_0200}BOOL
# {http://www.plcopen.org/xml/tc6_0200}variable
# {http://www.plcopen.org/xml/tc6_0200}type
# {http://www.plcopen.org/xml/tc6_0200}BOOL
# {http://www.plcopen.org/xml/tc6_0200}variable
# {http://www.plcopen.org/xml/tc6_0200}type
# {http://www.plcopen.org/xml/tc6_0200}BOOL
# {http://www.plcopen.org/xml/tc6_0200}variable
# {http://www.plcopen.org/xml/tc6_0200}type
# {http://www.plcopen.org/xml/tc6_0200}BOOL
# {http://www.plcopen.org/xml/tc6_0200}variable
# {http://www.plcopen.org/xml/tc6_0200}type
# {http://www.plcopen.org/xml/tc6_0200}BOOL
# {http://www.plcopen.org/xml/tc6_0200}variable
# {http://www.plcopen.org/xml/tc6_0200}type
# {http://www.plcopen.org/xml/tc6_0200}BOOL
# {http://www.plcopen.org/xml/tc6_0200}variable
# {http://www.plcopen.org/xml/tc6_0200}type
# {http://www.plcopen.org/xml/tc6_0200}BOOL
# {http://www.plcopen.org/xml/tc6_0200}variable
# {http://www.plcopen.org/xml/tc6_0200}type
# {http://www.plcopen.org/xml/tc6_0200}BOOL
# {http://www.plcopen.org/xml/tc6_0200}variable
# {http://www.plcopen.org/xml/tc6_0200}type
# {http://www.plcopen.org/xml/tc6_0200}BOOL
# {http://www.plcopen.org/xml/tc6_0200}variable
# {http://www.plcopen.org/xml/tc6_0200}type
# {http://www.plcopen.org/xml/tc6_0200}BOOL
# {http://www.plcopen.org/xml/tc6_0200}variable
# {http://www.plcopen.org/xml/tc6_0200}type
# {http://www.plcopen.org/xml/tc6_0200}BOOL
# {http://www.plcopen.org/xml/tc6_0200}variable
# {http://www.plcopen.org/xml/tc6_0200}type
# {http://www.plcopen.org/xml/tc6_0200}BOOL
# {http://www.plcopen.org/xml/tc6_0200}variable
# {http://www.plcopen.org/xml/tc6_0200}type
# {http://www.plcopen.org/xml/tc6_0200}BOOL
# {http://www.plcopen.org/xml/tc6_0200}variable
# {http://www.plcopen.org/xml/tc6_0200}type
# {http://www.plcopen.org/xml/tc6_0200}BOOL
# {http://www.plcopen.org/xml/tc6_0200}variable
# {http://www.plcopen.org/xml/tc6_0200}type
# {http://www.plcopen.org/xml/tc6_0200}BOOL
# {http://www.plcopen.org/xml/tc6_0200}variable
# {http://www.plcopen.org/xml/tc6_0200}type
# {http://www.plcopen.org/xml/tc6_0200}BOOL
# {http://www.plcopen.org/xml/tc6_0200}variable
# {http://www.plcopen.org/xml/tc6_0200}type
# {http://www.plcopen.org/xml/tc6_0200}BOOL
# {http://www.plcopen.org/xml/tc6_0200}variable
# {http://www.plcopen.org/xml/tc6_0200}type
# {http://www.plcopen.org/xml/tc6_0200}BOOL
# {http://www.plcopen.org/xml/tc6_0200}variable
# {http://www.plcopen.org/xml/tc6_0200}type
# {http://www.plcopen.org/xml/tc6_0200}BOOL
# {http://www.plcopen.org/xml/tc6_0200}variable
# {http://www.plcopen.org/xml/tc6_0200}type
# {http://www.plcopen.org/xml/tc6_0200}BOOL
# {http://www.plcopen.org/xml/tc6_0200}variable
# {http://www.plcopen.org/xml/tc6_0200}type
# {http://www.plcopen.org/xml/tc6_0200}BOOL
# {http://www.plcopen.org/xml/tc6_0200}variable
# {http://www.plcopen.org/xml/tc6_0200}type
# {http://www.plcopen.org/xml/tc6_0200}BOOL
# {http://www.plcopen.org/xml/tc6_0200}variable
# {http://www.plcopen.org/xml/tc6_0200}type
# {http://www.plcopen.org/xml/tc6_0200}BOOL
# {http://www.plcopen.org/xml/tc6_0200}variable
# {http://www.plcopen.org/xml/tc6_0200}type
# {http://www.plcopen.org/xml/tc6_0200}BOOL
# {http://www.plcopen.org/xml/tc6_0200}variable
# {http://www.plcopen.org/xml/tc6_0200}type
# {http://www.plcopen.org/xml/tc6_0200}BOOL
# {http://www.plcopen.org/xml/tc6_0200}variable
# {http://www.plcopen.org/xml/tc6_0200}type
# {http://www.plcopen.org/xml/tc6_0200}BOOL
# {http://www.plcopen.org/xml/tc6_0200}variable
# {http://www.plcopen.org/xml/tc6_0200}type
# {http://www.plcopen.org/xml/tc6_0200}BOOL
# {http://www.plcopen.org/xml/tc6_0200}variable
# {http://www.plcopen.org/xml/tc6_0200}type
# {http://www.plcopen.org/xml/tc6_0200}BOOL
# {http://www.plcopen.org/xml/tc6_0200}variable
# {http://www.plcopen.org/xml/tc6_0200}type
# {http://www.plcopen.org/xml/tc6_0200}BOOL
# {http://www.plcopen.org/xml/tc6_0200}variable
# {http://www.plcopen.org/xml/tc6_0200}type
# {http://www.plcopen.org/xml/tc6_0200}BOOL
# {http://www.plcopen.org/xml/tc6_0200}variable
# {http://www.plcopen.org/xml/tc6_0200}type
# {http://www.plcopen.org/xml/tc6_0200}BOOL
# {http://www.plcopen.org/xml/tc6_0200}variable
# {http://www.plcopen.org/xml/tc6_0200}type
# {http://www.plcopen.org/xml/tc6_0200}BOOL
# {http://www.plcopen.org/xml/tc6_0200}variable
# {http://www.plcopen.org/xml/tc6_0200}type
# {http://www.plcopen.org/xml/tc6_0200}BOOL
# {http://www.plcopen.org/xml/tc6_0200}variable
# {http://www.plcopen.org/xml/tc6_0200}type
# {http://www.plcopen.org/xml/tc6_0200}BOOL
# {http://www.plcopen.org/xml/tc6_0200}variable
# {http://www.plcopen.org/xml/tc6_0200}type
# {http://www.plcopen.org/xml/tc6_0200}BOOL
# {http://www.plcopen.org/xml/tc6_0200}variable
# {http://www.plcopen.org/xml/tc6_0200}type
# {http://www.plcopen.org/xml/tc6_0200}BOOL
# {http://www.plcopen.org/xml/tc6_0200}variable
# {http://www.plcopen.org/xml/tc6_0200}type
# {http://www.plcopen.org/xml/tc6_0200}BOOL
# {http://www.plcopen.org/xml/tc6_0200}variable
# {http://www.plcopen.org/xml/tc6_0200}type
# {http://www.plcopen.org/xml/tc6_0200}BOOL
# {http://www.plcopen.org/xml/tc6_0200}variable
# {http://www.plcopen.org/xml/tc6_0200}type
# {http://www.plcopen.org/xml/tc6_0200}BOOL
# {http://www.plcopen.org/xml/tc6_0200}variable
# {http://www.plcopen.org/xml/tc6_0200}type
# {http://www.plcopen.org/xml/tc6_0200}BOOL
# {http://www.plcopen.org/xml/tc6_0200}variable
# {http://www.plcopen.org/xml/tc6_0200}type
# {http://www.plcopen.org/xml/tc6_0200}BOOL
# {http://www.plcopen.org/xml/tc6_0200}variable
# {http://www.plcopen.org/xml/tc6_0200}type
# {http://www.plcopen.org/xml/tc6_0200}BOOL
# {http://www.plcopen.org/xml/tc6_0200}variable
# {http://www.plcopen.org/xml/tc6_0200}type
# {http://www.plcopen.org/xml/tc6_0200}BOOL
# {http://www.plcopen.org/xml/tc6_0200}variable
# {http://www.plcopen.org/xml/tc6_0200}type
# {http://www.plcopen.org/xml/tc6_0200}BOOL
# {http://www.plcopen.org/xml/tc6_0200}variable
# {http://www.plcopen.org/xml/tc6_0200}type
# {http://www.plcopen.org/xml/tc6_0200}BOOL
# {http://www.plcopen.org/xml/tc6_0200}variable
# {http://www.plcopen.org/xml/tc6_0200}type
# {http://www.plcopen.org/xml/tc6_0200}BOOL
# {http://www.plcopen.org/xml/tc6_0200}variable
# {http://www.plcopen.org/xml/tc6_0200}type
# {http://www.plcopen.org/xml/tc6_0200}BOOL
# {http://www.plcopen.org/xml/tc6_0200}variable
# {http://www.plcopen.org/xml/tc6_0200}type
# {http://www.plcopen.org/xml/tc6_0200}BOOL
# {http://www.plcopen.org/xml/tc6_0200}variable
# {http://www.plcopen.org/xml/tc6_0200}type
# {http://www.plcopen.org/xml/tc6_0200}BOOL
# {http://www.plcopen.org/xml/tc6_0200}variable
# {http://www.plcopen.org/xml/tc6_0200}type
# {http://www.plcopen.org/xml/tc6_0200}BOOL
# {http://www.plcopen.org/xml/tc6_0200}variable
# {http://www.plcopen.org/xml/tc6_0200}type
# {http://www.plcopen.org/xml/tc6_0200}BOOL
# {http://www.plcopen.org/xml/tc6_0200}variable
# {http://www.plcopen.org/xml/tc6_0200}type
# {http://www.plcopen.org/xml/tc6_0200}BOOL
# {http://www.plcopen.org/xml/tc6_0200}variable
# {http://www.plcopen.org/xml/tc6_0200}type
# {http://www.plcopen.org/xml/tc6_0200}BOOL
# {http://www.plcopen.org/xml/tc6_0200}variable
# {http://www.plcopen.org/xml/tc6_0200}type
# {http://www.plcopen.org/xml/tc6_0200}BOOL
# {http://www.plcopen.org/xml/tc6_0200}variable
# {http://www.plcopen.org/xml/tc6_0200}type
# {http://www.plcopen.org/xml/tc6_0200}BOOL
# {http://www.plcopen.org/xml/tc6_0200}variable
# {http://www.plcopen.org/xml/tc6_0200}type
# {http://www.plcopen.org/xml/tc6_0200}BOOL
# {http://www.plcopen.org/xml/tc6_0200}variable
# {http://www.plcopen.org/xml/tc6_0200}type
# {http://www.plcopen.org/xml/tc6_0200}BOOL
# {http://www.plcopen.org/xml/tc6_0200}variable
# {http://www.plcopen.org/xml/tc6_0200}type
# {http://www.plcopen.org/xml/tc6_0200}BOOL
# {http://www.plcopen.org/xml/tc6_0200}variable
# {http://www.plcopen.org/xml/tc6_0200}type
# {http://www.plcopen.org/xml/tc6_0200}BOOL
# {http://www.plcopen.org/xml/tc6_0200}variable
# {http://www.plcopen.org/xml/tc6_0200}type
# {http://www.plcopen.org/xml/tc6_0200}BOOL
# {http://www.plcopen.org/xml/tc6_0200}variable
# {http://www.plcopen.org/xml/tc6_0200}type
# {http://www.plcopen.org/xml/tc6_0200}BOOL
# {http://www.plcopen.org/xml/tc6_0200}variable
# {http://www.plcopen.org/xml/tc6_0200}type
# {http://www.plcopen.org/xml/tc6_0200}BOOL
# {http://www.plcopen.org/xml/tc6_0200}variable
# {http://www.plcopen.org/xml/tc6_0200}type
# {http://www.plcopen.org/xml/tc6_0200}BOOL
# {http://www.plcopen.org/xml/tc6_0200}variable
# {http://www.plcopen.org/xml/tc6_0200}type
# {http://www.plcopen.org/xml/tc6_0200}BOOL
# {http://www.plcopen.org/xml/tc6_0200}variable
# {http://www.plcopen.org/xml/tc6_0200}type
# {http://www.plcopen.org/xml/tc6_0200}BOOL
# {http://www.plcopen.org/xml/tc6_0200}variable
# {http://www.plcopen.org/xml/tc6_0200}type
# {http://www.plcopen.org/xml/tc6_0200}BOOL
# {http://www.plcopen.org/xml/tc6_0200}variable
# {http://www.plcopen.org/xml/tc6_0200}type
# {http://www.plcopen.org/xml/tc6_0200}BOOL
# {http://www.plcopen.org/xml/tc6_0200}variable
# {http://www.plcopen.org/xml/tc6_0200}type
# {http://www.plcopen.org/xml/tc6_0200}BOOL
# {http://www.plcopen.org/xml/tc6_0200}variable
# {http://www.plcopen.org/xml/tc6_0200}type
# {http://www.plcopen.org/xml/tc6_0200}BOOL
# {http://www.plcopen.org/xml/tc6_0200}documentation
# {http://www.w3.org/1999/xhtml}xhtml
# {http://www.plcopen.org/xml/tc6_0200}variable
# {http://www.plcopen.org/xml/tc6_0200}type
# {http://www.plcopen.org/xml/tc6_0200}BOOL
# {http://www.plcopen.org/xml/tc6_0200}variable
# {http://www.plcopen.org/xml/tc6_0200}type
# {http://www.plcopen.org/xml/tc6_0200}BOOL
# {http://www.plcopen.org/xml/tc6_0200}variable
# {http://www.plcopen.org/xml/tc6_0200}type
# {http://www.plcopen.org/xml/tc6_0200}BOOL
# {http://www.plcopen.org/xml/tc6_0200}variable
# {http://www.plcopen.org/xml/tc6_0200}type
# {http://www.plcopen.org/xml/tc6_0200}BOOL
# {http://www.plcopen.org/xml/tc6_0200}variable
# {http://www.plcopen.org/xml/tc6_0200}type
# {http://www.plcopen.org/xml/tc6_0200}BOOL
# {http://www.plcopen.org/xml/tc6_0200}variable
# {http://www.plcopen.org/xml/tc6_0200}type
# {http://www.plcopen.org/xml/tc6_0200}BOOL
# {http://www.plcopen.org/xml/tc6_0200}variable
# {http://www.plcopen.org/xml/tc6_0200}type
# {http://www.plcopen.org/xml/tc6_0200}BOOL
# {http://www.plcopen.org/xml/tc6_0200}variable
# {http://www.plcopen.org/xml/tc6_0200}type
# {http://www.plcopen.org/xml/tc6_0200}BOOL
# {http://www.plcopen.org/xml/tc6_0200}variable
# {http://www.plcopen.org/xml/tc6_0200}type
# {http://www.plcopen.org/xml/tc6_0200}BOOL
# {http://www.plcopen.org/xml/tc6_0200}variable
# {http://www.plcopen.org/xml/tc6_0200}type
# {http://www.plcopen.org/xml/tc6_0200}BOOL
# {http://www.plcopen.org/xml/tc6_0200}variable
# {http://www.plcopen.org/xml/tc6_0200}type
# {http://www.plcopen.org/xml/tc6_0200}BOOL
# {http://www.plcopen.org/xml/tc6_0200}variable
# {http://www.plcopen.org/xml/tc6_0200}type
# {http://www.plcopen.org/xml/tc6_0200}BOOL
# {http://www.plcopen.org/xml/tc6_0200}variable
# {http://www.plcopen.org/xml/tc6_0200}type
# {http://www.plcopen.org/xml/tc6_0200}BOOL
# {http://www.plcopen.org/xml/tc6_0200}variable
# {http://www.plcopen.org/xml/tc6_0200}type
# {http://www.plcopen.org/xml/tc6_0200}BOOL
# {http://www.plcopen.org/xml/tc6_0200}variable
# {http://www.plcopen.org/xml/tc6_0200}type
# {http://www.plcopen.org/xml/tc6_0200}BOOL
# {http://www.plcopen.org/xml/tc6_0200}variable
# {http://www.plcopen.org/xml/tc6_0200}type
# {http://www.plcopen.org/xml/tc6_0200}BOOL
# {http://www.plcopen.org/xml/tc6_0200}variable
# {http://www.plcopen.org/xml/tc6_0200}type
# {http://www.plcopen.org/xml/tc6_0200}BOOL
# {http://www.plcopen.org/xml/tc6_0200}variable
# {http://www.plcopen.org/xml/tc6_0200}type
# {http://www.plcopen.org/xml/tc6_0200}BOOL
# {http://www.plcopen.org/xml/tc6_0200}variable
# {http://www.plcopen.org/xml/tc6_0200}type
# {http://www.plcopen.org/xml/tc6_0200}BOOL
# {http://www.plcopen.org/xml/tc6_0200}variable
# {http://www.plcopen.org/xml/tc6_0200}type
# {http://www.plcopen.org/xml/tc6_0200}BOOL
# {http://www.plcopen.org/xml/tc6_0200}variable
# {http://www.plcopen.org/xml/tc6_0200}type
# {http://www.plcopen.org/xml/tc6_0200}BOOL
# {http://www.plcopen.org/xml/tc6_0200}variable
# {http://www.plcopen.org/xml/tc6_0200}type
# {http://www.plcopen.org/xml/tc6_0200}BOOL
# {http://www.plcopen.org/xml/tc6_0200}variable
# {http://www.plcopen.org/xml/tc6_0200}type
# {http://www.plcopen.org/xml/tc6_0200}BOOL
# {http://www.plcopen.org/xml/tc6_0200}variable
# {http://www.plcopen.org/xml/tc6_0200}type
# {http://www.plcopen.org/xml/tc6_0200}BOOL
# {http://www.plcopen.org/xml/tc6_0200}variable
# {http://www.plcopen.org/xml/tc6_0200}type
# {http://www.plcopen.org/xml/tc6_0200}BOOL
# {http://www.plcopen.org/xml/tc6_0200}variable
# {http://www.plcopen.org/xml/tc6_0200}type
# {http://www.plcopen.org/xml/tc6_0200}BOOL
# {http://www.plcopen.org/xml/tc6_0200}variable
# {http://www.plcopen.org/xml/tc6_0200}type
# {http://www.plcopen.org/xml/tc6_0200}BOOL
# {http://www.plcopen.org/xml/tc6_0200}variable
# {http://www.plcopen.org/xml/tc6_0200}type
# {http://www.plcopen.org/xml/tc6_0200}BOOL
# {http://www.plcopen.org/xml/tc6_0200}variable
# {http://www.plcopen.org/xml/tc6_0200}type
# {http://www.plcopen.org/xml/tc6_0200}BOOL
# {http://www.plcopen.org/xml/tc6_0200}variable
# {http://www.plcopen.org/xml/tc6_0200}type
# {http://www.plcopen.org/xml/tc6_0200}BOOL
# {http://www.plcopen.org/xml/tc6_0200}variable
# {http://www.plcopen.org/xml/tc6_0200}type
# {http://www.plcopen.org/xml/tc6_0200}BOOL
# {http://www.plcopen.org/xml/tc6_0200}variable
# {http://www.plcopen.org/xml/tc6_0200}type
# {http://www.plcopen.org/xml/tc6_0200}BOOL
# {http://www.plcopen.org/xml/tc6_0200}variable
# {http://www.plcopen.org/xml/tc6_0200}type
# {http://www.plcopen.org/xml/tc6_0200}BOOL
# {http://www.plcopen.org/xml/tc6_0200}variable
# {http://www.plcopen.org/xml/tc6_0200}type
# {http://www.plcopen.org/xml/tc6_0200}BOOL
# {http://www.plcopen.org/xml/tc6_0200}globalVars
# {http://www.plcopen.org/xml/tc6_0200}variable
# {http://www.plcopen.org/xml/tc6_0200}type
# {http://www.plcopen.org/xml/tc6_0200}BOOL
# {http://www.plcopen.org/xml/tc6_0200}variable
# {http://www.plcopen.org/xml/tc6_0200}type
# {http://www.plcopen.org/xml/tc6_0200}BOOL
# {http://www.plcopen.org/xml/tc6_0200}variable
# {http://www.plcopen.org/xml/tc6_0200}type
# {http://www.plcopen.org/xml/tc6_0200}BOOL
# {http://www.plcopen.org/xml/tc6_0200}variable
# {http://www.plcopen.org/xml/tc6_0200}type
# {http://www.plcopen.org/xml/tc6_0200}BOOL
# {http://www.plcopen.org/xml/tc6_0200}variable
# {http://www.plcopen.org/xml/tc6_0200}type
# {http://www.plcopen.org/xml/tc6_0200}BOOL
# {http://www.plcopen.org/xml/tc6_0200}variable
# {http://www.plcopen.org/xml/tc6_0200}type
# {http://www.plcopen.org/xml/tc6_0200}BOOL
# {http://www.plcopen.org/xml/tc6_0200}variable
# {http://www.plcopen.org/xml/tc6_0200}type
# {http://www.plcopen.org/xml/tc6_0200}BOOL
# {http://www.plcopen.org/xml/tc6_0200}variable
# {http://www.plcopen.org/xml/tc6_0200}type
# {http://www.plcopen.org/xml/tc6_0200}BOOL
# {http://www.plcopen.org/xml/tc6_0200}variable
# {http://www.plcopen.org/xml/tc6_0200}type
# {http://www.plcopen.org/xml/tc6_0200}BOOL
# {http://www.plcopen.org/xml/tc6_0200}variable
# {http://www.plcopen.org/xml/tc6_0200}type
# {http://www.plcopen.org/xml/tc6_0200}BOOL
# {http://www.plcopen.org/xml/tc6_0200}variable
# {http://www.plcopen.org/xml/tc6_0200}type
# {http://www.plcopen.org/xml/tc6_0200}BOOL
# {http://www.plcopen.org/xml/tc6_0200}variable
# {http://www.plcopen.org/xml/tc6_0200}type
# {http://www.plcopen.org/xml/tc6_0200}BOOL
# {http://www.plcopen.org/xml/tc6_0200}variable
# {http://www.plcopen.org/xml/tc6_0200}type
# {http://www.plcopen.org/xml/tc6_0200}BOOL
# {http://www.plcopen.org/xml/tc6_0200}variable
# {http://www.plcopen.org/xml/tc6_0200}type
# {http://www.plcopen.org/xml/tc6_0200}BOOL
# {http://www.plcopen.org/xml/tc6_0200}variable
# {http://www.plcopen.org/xml/tc6_0200}type
# {http://www.plcopen.org/xml/tc6_0200}BOOL
# {http://www.plcopen.org/xml/tc6_0200}variable
# {http://www.plcopen.org/xml/tc6_0200}type
# {http://www.plcopen.org/xml/tc6_0200}BOOL
# {http://www.plcopen.org/xml/tc6_0200}variable
# {http://www.plcopen.org/xml/tc6_0200}type
# {http://www.plcopen.org/xml/tc6_0200}BOOL
# {http://www.plcopen.org/xml/tc6_0200}variable
# {http://www.plcopen.org/xml/tc6_0200}type
# {http://www.plcopen.org/xml/tc6_0200}BOOL
# {http://www.plcopen.org/xml/tc6_0200}variable
# {http://www.plcopen.org/xml/tc6_0200}type
# {http://www.plcopen.org/xml/tc6_0200}BOOL
# {http://www.plcopen.org/xml/tc6_0200}variable
# {http://www.plcopen.org/xml/tc6_0200}type
# {http://www.plcopen.org/xml/tc6_0200}BOOL
# {http://www.plcopen.org/xml/tc6_0200}variable
# {http://www.plcopen.org/xml/tc6_0200}type
# {http://www.plcopen.org/xml/tc6_0200}BOOL
# {http://www.plcopen.org/xml/tc6_0200}variable
# {http://www.plcopen.org/xml/tc6_0200}type
# {http://www.plcopen.org/xml/tc6_0200}BOOL
# {http://www.plcopen.org/xml/tc6_0200}variable
# {http://www.plcopen.org/xml/tc6_0200}type
# {http://www.plcopen.org/xml/tc6_0200}BOOL
# {http://www.plcopen.org/xml/tc6_0200}variable
# {http://www.plcopen.org/xml/tc6_0200}type
# {http://www.plcopen.org/xml/tc6_0200}BOOL
# {http://www.plcopen.org/xml/tc6_0200}variable
# {http://www.plcopen.org/xml/tc6_0200}type
# {http://www.plcopen.org/xml/tc6_0200}INT
# {http://www.plcopen.org/xml/tc6_0200}variable
# {http://www.plcopen.org/xml/tc6_0200}type
# {http://www.plcopen.org/xml/tc6_0200}INT
# {http://www.plcopen.org/xml/tc6_0200}variable
# {http://www.plcopen.org/xml/tc6_0200}type
# {http://www.plcopen.org/xml/tc6_0200}INT
# {http://www.plcopen.org/xml/tc6_0200}variable
# {http://www.plcopen.org/xml/tc6_0200}type
# {http://www.plcopen.org/xml/tc6_0200}INT
# {http://www.plcopen.org/xml/tc6_0200}variable
# {http://www.plcopen.org/xml/tc6_0200}type
# {http://www.plcopen.org/xml/tc6_0200}INT
# {http://www.plcopen.org/xml/tc6_0200}variable
# {http://www.plcopen.org/xml/tc6_0200}type
# {http://www.plcopen.org/xml/tc6_0200}DINT
# {http://www.plcopen.org/xml/tc6_0200}addData
# {http://www.plcopen.org/xml/tc6_0200}data
# {http://www.plcopen.org/xml/tc6_0200}MixedAttrsVarList
# {http://www.plcopen.org/xml/tc6_0200}globalVars
# {http://www.plcopen.org/xml/tc6_0200}variable
# {http://www.plcopen.org/xml/tc6_0200}type
# {http://www.plcopen.org/xml/tc6_0200}BOOL
# {http://www.plcopen.org/xml/tc6_0200}variable
# {http://www.plcopen.org/xml/tc6_0200}type
# {http://www.plcopen.org/xml/tc6_0200}BOOL
# {http://www.plcopen.org/xml/tc6_0200}variable
# {http://www.plcopen.org/xml/tc6_0200}type
# {http://www.plcopen.org/xml/tc6_0200}BOOL
# {http://www.plcopen.org/xml/tc6_0200}variable
# {http://www.plcopen.org/xml/tc6_0200}type
# {http://www.plcopen.org/xml/tc6_0200}BOOL
# {http://www.plcopen.org/xml/tc6_0200}variable
# {http://www.plcopen.org/xml/tc6_0200}type
# {http://www.plcopen.org/xml/tc6_0200}BOOL
# {http://www.plcopen.org/xml/tc6_0200}variable
# {http://www.plcopen.org/xml/tc6_0200}type
# {http://www.plcopen.org/xml/tc6_0200}BOOL
# {http://www.plcopen.org/xml/tc6_0200}variable
# {http://www.plcopen.org/xml/tc6_0200}type
# {http://www.plcopen.org/xml/tc6_0200}BOOL
# {http://www.plcopen.org/xml/tc6_0200}variable
# {http://www.plcopen.org/xml/tc6_0200}type
# {http://www.plcopen.org/xml/tc6_0200}BOOL
# {http://www.plcopen.org/xml/tc6_0200}variable
# {http://www.plcopen.org/xml/tc6_0200}type
# {http://www.plcopen.org/xml/tc6_0200}BOOL
# {http://www.plcopen.org/xml/tc6_0200}variable
# {http://www.plcopen.org/xml/tc6_0200}type
# {http://www.plcopen.org/xml/tc6_0200}BOOL
# {http://www.plcopen.org/xml/tc6_0200}variable
# {http://www.plcopen.org/xml/tc6_0200}type
# {http://www.plcopen.org/xml/tc6_0200}BOOL
# {http://www.plcopen.org/xml/tc6_0200}variable
# {http://www.plcopen.org/xml/tc6_0200}type
# {http://www.plcopen.org/xml/tc6_0200}BOOL
# {http://www.plcopen.org/xml/tc6_0200}variable
# {http://www.plcopen.org/xml/tc6_0200}type
# {http://www.plcopen.org/xml/tc6_0200}BOOL
# {http://www.plcopen.org/xml/tc6_0200}variable
# {http://www.plcopen.org/xml/tc6_0200}type
# {http://www.plcopen.org/xml/tc6_0200}BOOL
# {http://www.plcopen.org/xml/tc6_0200}variable
# {http://www.plcopen.org/xml/tc6_0200}type
# {http://www.plcopen.org/xml/tc6_0200}BOOL
# {http://www.plcopen.org/xml/tc6_0200}variable
# {http://www.plcopen.org/xml/tc6_0200}type
# {http://www.plcopen.org/xml/tc6_0200}BOOL
# {http://www.plcopen.org/xml/tc6_0200}variable
# {http://www.plcopen.org/xml/tc6_0200}type
# {http://www.plcopen.org/xml/tc6_0200}BOOL
# {http://www.plcopen.org/xml/tc6_0200}variable
# {http://www.plcopen.org/xml/tc6_0200}type
# {http://www.plcopen.org/xml/tc6_0200}BOOL
# {http://www.plcopen.org/xml/tc6_0200}variable
# {http://www.plcopen.org/xml/tc6_0200}type
# {http://www.plcopen.org/xml/tc6_0200}BOOL
# {http://www.plcopen.org/xml/tc6_0200}variable
# {http://www.plcopen.org/xml/tc6_0200}type
# {http://www.plcopen.org/xml/tc6_0200}BOOL
# {http://www.plcopen.org/xml/tc6_0200}variable
# {http://www.plcopen.org/xml/tc6_0200}type
# {http://www.plcopen.org/xml/tc6_0200}BOOL
# {http://www.plcopen.org/xml/tc6_0200}variable
# {http://www.plcopen.org/xml/tc6_0200}type
# {http://www.plcopen.org/xml/tc6_0200}BOOL
# {http://www.plcopen.org/xml/tc6_0200}variable
# {http://www.plcopen.org/xml/tc6_0200}type
# {http://www.plcopen.org/xml/tc6_0200}BOOL
# {http://www.plcopen.org/xml/tc6_0200}variable
# {http://www.plcopen.org/xml/tc6_0200}type
# {http://www.plcopen.org/xml/tc6_0200}BOOL
# {http://www.plcopen.org/xml/tc6_0200}variable
# {http://www.plcopen.org/xml/tc6_0200}type
# {http://www.plcopen.org/xml/tc6_0200}INT
# {http://www.plcopen.org/xml/tc6_0200}variable
# {http://www.plcopen.org/xml/tc6_0200}type
# {http://www.plcopen.org/xml/tc6_0200}INT
# {http://www.plcopen.org/xml/tc6_0200}variable
# {http://www.plcopen.org/xml/tc6_0200}type
# {http://www.plcopen.org/xml/tc6_0200}INT
# {http://www.plcopen.org/xml/tc6_0200}variable
# {http://www.plcopen.org/xml/tc6_0200}type
# {http://www.plcopen.org/xml/tc6_0200}INT
# {http://www.plcopen.org/xml/tc6_0200}globalVars
# {http://www.plcopen.org/xml/tc6_0200}variable
# {http://www.plcopen.org/xml/tc6_0200}type
# {http://www.plcopen.org/xml/tc6_0200}INT
# {http://www.plcopen.org/xml/tc6_0200}variable
# {http://www.plcopen.org/xml/tc6_0200}type
# {http://www.plcopen.org/xml/tc6_0200}DINT
# {http://www.plcopen.org/xml/tc6_0200}globalVars
# {http://www.plcopen.org/xml/tc6_0200}variable
# {http://www.plcopen.org/xml/tc6_0200}type
# {http://www.plcopen.org/xml/tc6_0200}BOOL
# {http://www.plcopen.org/xml/tc6_0200}variable
# {http://www.plcopen.org/xml/tc6_0200}type
# {http://www.plcopen.org/xml/tc6_0200}BOOL
# {http://www.plcopen.org/xml/tc6_0200}variable
# {http://www.plcopen.org/xml/tc6_0200}type
# {http://www.plcopen.org/xml/tc6_0200}BOOL
# {http://www.plcopen.org/xml/tc6_0200}variable
# {http://www.plcopen.org/xml/tc6_0200}type
# {http://www.plcopen.org/xml/tc6_0200}BOOL
# {http://www.plcopen.org/xml/tc6_0200}variable
# {http://www.plcopen.org/xml/tc6_0200}type
# {http://www.plcopen.org/xml/tc6_0200}BOOL
# {http://www.plcopen.org/xml/tc6_0200}variable
# {http://www.plcopen.org/xml/tc6_0200}type
# {http://www.plcopen.org/xml/tc6_0200}BOOL
# {http://www.plcopen.org/xml/tc6_0200}variable
# {http://www.plcopen.org/xml/tc6_0200}type
# {http://www.plcopen.org/xml/tc6_0200}BOOL
# {http://www.plcopen.org/xml/tc6_0200}variable
# {http://www.plcopen.org/xml/tc6_0200}type
# {http://www.plcopen.org/xml/tc6_0200}BOOL
# {http://www.plcopen.org/xml/tc6_0200}variable
# {http://www.plcopen.org/xml/tc6_0200}type
# {http://www.plcopen.org/xml/tc6_0200}BOOL
# {http://www.plcopen.org/xml/tc6_0200}variable
# {http://www.plcopen.org/xml/tc6_0200}type
# {http://www.plcopen.org/xml/tc6_0200}BOOL
# {http://www.plcopen.org/xml/tc6_0200}variable
# {http://www.plcopen.org/xml/tc6_0200}type
# {http://www.plcopen.org/xml/tc6_0200}BOOL
# {http://www.plcopen.org/xml/tc6_0200}variable
# {http://www.plcopen.org/xml/tc6_0200}type
# {http://www.plcopen.org/xml/tc6_0200}BOOL
# {http://www.plcopen.org/xml/tc6_0200}variable
# {http://www.plcopen.org/xml/tc6_0200}type
# {http://www.plcopen.org/xml/tc6_0200}BOOL
# {http://www.plcopen.org/xml/tc6_0200}variable
# {http://www.plcopen.org/xml/tc6_0200}type
# {http://www.plcopen.org/xml/tc6_0200}BOOL
# {http://www.plcopen.org/xml/tc6_0200}variable
# {http://www.plcopen.org/xml/tc6_0200}type
# {http://www.plcopen.org/xml/tc6_0200}BOOL
# {http://www.plcopen.org/xml/tc6_0200}variable
# {http://www.plcopen.org/xml/tc6_0200}type
# {http://www.plcopen.org/xml/tc6_0200}BOOL
# {http://www.plcopen.org/xml/tc6_0200}documentation
# {http://www.w3.org/1999/xhtml}xhtml
# {http://www.plcopen.org/xml/tc6_0200}variable
# {http://www.plcopen.org/xml/tc6_0200}type
# {http://www.plcopen.org/xml/tc6_0200}BOOL
# {http://www.plcopen.org/xml/tc6_0200}variable
# {http://www.plcopen.org/xml/tc6_0200}type
# {http://www.plcopen.org/xml/tc6_0200}BOOL
# {http://www.plcopen.org/xml/tc6_0200}variable
# {http://www.plcopen.org/xml/tc6_0200}type
# {http://www.plcopen.org/xml/tc6_0200}BOOL
# {http://www.plcopen.org/xml/tc6_0200}variable
# {http://www.plcopen.org/xml/tc6_0200}type
# {http://www.plcopen.org/xml/tc6_0200}BOOL
# {http://www.plcopen.org/xml/tc6_0200}variable
# {http://www.plcopen.org/xml/tc6_0200}type
# {http://www.plcopen.org/xml/tc6_0200}BOOL
# {http://www.plcopen.org/xml/tc6_0200}variable
# {http://www.plcopen.org/xml/tc6_0200}type
# {http://www.plcopen.org/xml/tc6_0200}BOOL
# {http://www.plcopen.org/xml/tc6_0200}variable
# {http://www.plcopen.org/xml/tc6_0200}type
# {http://www.plcopen.org/xml/tc6_0200}BOOL
# {http://www.plcopen.org/xml/tc6_0200}variable
# {http://www.plcopen.org/xml/tc6_0200}type
# {http://www.plcopen.org/xml/tc6_0200}BOOL
# {http://www.plcopen.org/xml/tc6_0200}variable
# {http://www.plcopen.org/xml/tc6_0200}type
# {http://www.plcopen.org/xml/tc6_0200}BOOL
# {http://www.plcopen.org/xml/tc6_0200}variable
# {http://www.plcopen.org/xml/tc6_0200}type
# {http://www.plcopen.org/xml/tc6_0200}BOOL
# {http://www.plcopen.org/xml/tc6_0200}variable
# {http://www.plcopen.org/xml/tc6_0200}type
# {http://www.plcopen.org/xml/tc6_0200}BOOL
# {http://www.plcopen.org/xml/tc6_0200}variable
# {http://www.plcopen.org/xml/tc6_0200}type
# {http://www.plcopen.org/xml/tc6_0200}BOOL
# {http://www.plcopen.org/xml/tc6_0200}variable
# {http://www.plcopen.org/xml/tc6_0200}type
# {http://www.plcopen.org/xml/tc6_0200}BOOL
# {http://www.plcopen.org/xml/tc6_0200}variable
# {http://www.plcopen.org/xml/tc6_0200}type
# {http://www.plcopen.org/xml/tc6_0200}BOOL
# {http://www.plcopen.org/xml/tc6_0200}variable
# {http://www.plcopen.org/xml/tc6_0200}type
# {http://www.plcopen.org/xml/tc6_0200}BOOL
# {http://www.plcopen.org/xml/tc6_0200}variable
# {http://www.plcopen.org/xml/tc6_0200}type
# {http://www.plcopen.org/xml/tc6_0200}BOOL
# {http://www.plcopen.org/xml/tc6_0200}variable
# {http://www.plcopen.org/xml/tc6_0200}type
# {http://www.plcopen.org/xml/tc6_0200}BOOL
# {http://www.plcopen.org/xml/tc6_0200}variable
# {http://www.plcopen.org/xml/tc6_0200}type
# {http://www.plcopen.org/xml/tc6_0200}BOOL
# {http://www.plcopen.org/xml/tc6_0200}variable
# {http://www.plcopen.org/xml/tc6_0200}type
# {http://www.plcopen.org/xml/tc6_0200}BOOL
# {http://www.plcopen.org/xml/tc6_0200}variable
# {http://www.plcopen.org/xml/tc6_0200}type
# {http://www.plcopen.org/xml/tc6_0200}BOOL
# {http://www.plcopen.org/xml/tc6_0200}variable
# {http://www.plcopen.org/xml/tc6_0200}type
# {http://www.plcopen.org/xml/tc6_0200}BOOL
# {http://www.plcopen.org/xml/tc6_0200}variable
# {http://www.plcopen.org/xml/tc6_0200}type
# {http://www.plcopen.org/xml/tc6_0200}BOOL
# {http://www.plcopen.org/xml/tc6_0200}variable
# {http://www.plcopen.org/xml/tc6_0200}type
# {http://www.plcopen.org/xml/tc6_0200}BOOL
# {http://www.plcopen.org/xml/tc6_0200}variable
# {http://www.plcopen.org/xml/tc6_0200}type
# {http://www.plcopen.org/xml/tc6_0200}BOOL
# {http://www.plcopen.org/xml/tc6_0200}variable
# {http://www.plcopen.org/xml/tc6_0200}type
# {http://www.plcopen.org/xml/tc6_0200}BOOL
# {http://www.plcopen.org/xml/tc6_0200}variable
# {http://www.plcopen.org/xml/tc6_0200}type
# {http://www.plcopen.org/xml/tc6_0200}BOOL
# {http://www.plcopen.org/xml/tc6_0200}documentation
# {http://www.w3.org/1999/xhtml}xhtml
# {http://www.plcopen.org/xml/tc6_0200}variable
# {http://www.plcopen.org/xml/tc6_0200}type
# {http://www.plcopen.org/xml/tc6_0200}BOOL
# {http://www.plcopen.org/xml/tc6_0200}variable
# {http://www.plcopen.org/xml/tc6_0200}type
# {http://www.plcopen.org/xml/tc6_0200}BOOL
# {http://www.plcopen.org/xml/tc6_0200}variable
# {http://www.plcopen.org/xml/tc6_0200}type
# {http://www.plcopen.org/xml/tc6_0200}BOOL
# {http://www.plcopen.org/xml/tc6_0200}variable
# {http://www.plcopen.org/xml/tc6_0200}type
# {http://www.plcopen.org/xml/tc6_0200}BOOL
# {http://www.plcopen.org/xml/tc6_0200}variable
# {http://www.plcopen.org/xml/tc6_0200}type
# {http://www.plcopen.org/xml/tc6_0200}BOOL
# {http://www.plcopen.org/xml/tc6_0200}variable
# {http://www.plcopen.org/xml/tc6_0200}type
# {http://www.plcopen.org/xml/tc6_0200}BOOL
# {http://www.plcopen.org/xml/tc6_0200}variable
# {http://www.plcopen.org/xml/tc6_0200}type
# {http://www.plcopen.org/xml/tc6_0200}BOOL
# {http://www.plcopen.org/xml/tc6_0200}variable
# {http://www.plcopen.org/xml/tc6_0200}type
# {http://www.plcopen.org/xml/tc6_0200}BOOL
# {http://www.plcopen.org/xml/tc6_0200}variable
# {http://www.plcopen.org/xml/tc6_0200}type
# {http://www.plcopen.org/xml/tc6_0200}BOOL
# {http://www.plcopen.org/xml/tc6_0200}variable
# {http://www.plcopen.org/xml/tc6_0200}type
# {http://www.plcopen.org/xml/tc6_0200}BOOL
# {http://www.plcopen.org/xml/tc6_0200}variable
# {http://www.plcopen.org/xml/tc6_0200}type
# {http://www.plcopen.org/xml/tc6_0200}BOOL
# {http://www.plcopen.org/xml/tc6_0200}variable
# {http://www.plcopen.org/xml/tc6_0200}type
# {http://www.plcopen.org/xml/tc6_0200}BOOL
# {http://www.plcopen.org/xml/tc6_0200}variable
# {http://www.plcopen.org/xml/tc6_0200}type
# {http://www.plcopen.org/xml/tc6_0200}BOOL
# {http://www.plcopen.org/xml/tc6_0200}variable
# {http://www.plcopen.org/xml/tc6_0200}type
# {http://www.plcopen.org/xml/tc6_0200}BOOL
# {http://www.plcopen.org/xml/tc6_0200}variable
# {http://www.plcopen.org/xml/tc6_0200}type
# {http://www.plcopen.org/xml/tc6_0200}BOOL
# {http://www.plcopen.org/xml/tc6_0200}variable
# {http://www.plcopen.org/xml/tc6_0200}type
# {http://www.plcopen.org/xml/tc6_0200}BOOL
# {http://www.plcopen.org/xml/tc6_0200}variable
# {http://www.plcopen.org/xml/tc6_0200}type
# {http://www.plcopen.org/xml/tc6_0200}BOOL
# {http://www.plcopen.org/xml/tc6_0200}variable
# {http://www.plcopen.org/xml/tc6_0200}type
# {http://www.plcopen.org/xml/tc6_0200}BOOL
# {http://www.plcopen.org/xml/tc6_0200}variable
# {http://www.plcopen.org/xml/tc6_0200}type
# {http://www.plcopen.org/xml/tc6_0200}BOOL
# {http://www.plcopen.org/xml/tc6_0200}variable
# {http://www.plcopen.org/xml/tc6_0200}type
# {http://www.plcopen.org/xml/tc6_0200}BOOL
# {http://www.plcopen.org/xml/tc6_0200}variable
# {http://www.plcopen.org/xml/tc6_0200}type
# {http://www.plcopen.org/xml/tc6_0200}BOOL
# {http://www.plcopen.org/xml/tc6_0200}variable
# {http://www.plcopen.org/xml/tc6_0200}type
# {http://www.plcopen.org/xml/tc6_0200}BOOL
# {http://www.plcopen.org/xml/tc6_0200}variable
# {http://www.plcopen.org/xml/tc6_0200}type
# {http://www.plcopen.org/xml/tc6_0200}BOOL
# {http://www.plcopen.org/xml/tc6_0200}variable
# {http://www.plcopen.org/xml/tc6_0200}type
# {http://www.plcopen.org/xml/tc6_0200}BOOL
# {http://www.plcopen.org/xml/tc6_0200}variable
# {http://www.plcopen.org/xml/tc6_0200}type
# {http://www.plcopen.org/xml/tc6_0200}BOOL
# {http://www.plcopen.org/xml/tc6_0200}variable
# {http://www.plcopen.org/xml/tc6_0200}type
# {http://www.plcopen.org/xml/tc6_0200}BOOL
# {http://www.plcopen.org/xml/tc6_0200}documentation
# {http://www.w3.org/1999/xhtml}xhtml
# {http://www.plcopen.org/xml/tc6_0200}variable
# {http://www.plcopen.org/xml/tc6_0200}type
# {http://www.plcopen.org/xml/tc6_0200}BOOL
# {http://www.plcopen.org/xml/tc6_0200}variable
# {http://www.plcopen.org/xml/tc6_0200}type
# {http://www.plcopen.org/xml/tc6_0200}BOOL
# {http://www.plcopen.org/xml/tc6_0200}variable
# {http://www.plcopen.org/xml/tc6_0200}type
# {http://www.plcopen.org/xml/tc6_0200}BOOL
# {http://www.plcopen.org/xml/tc6_0200}variable
# {http://www.plcopen.org/xml/tc6_0200}type
# {http://www.plcopen.org/xml/tc6_0200}BOOL
# {http://www.plcopen.org/xml/tc6_0200}variable
# {http://www.plcopen.org/xml/tc6_0200}type
# {http://www.plcopen.org/xml/tc6_0200}BOOL
# {http://www.plcopen.org/xml/tc6_0200}variable
# {http://www.plcopen.org/xml/tc6_0200}type
# {http://www.plcopen.org/xml/tc6_0200}BOOL
# {http://www.plcopen.org/xml/tc6_0200}variable
# {http://www.plcopen.org/xml/tc6_0200}type
# {http://www.plcopen.org/xml/tc6_0200}BOOL
# {http://www.plcopen.org/xml/tc6_0200}variable
# {http://www.plcopen.org/xml/tc6_0200}type
# {http://www.plcopen.org/xml/tc6_0200}BOOL
# {http://www.plcopen.org/xml/tc6_0200}variable
# {http://www.plcopen.org/xml/tc6_0200}type
# {http://www.plcopen.org/xml/tc6_0200}BOOL
# {http://www.plcopen.org/xml/tc6_0200}variable
# {http://www.plcopen.org/xml/tc6_0200}type
# {http://www.plcopen.org/xml/tc6_0200}BOOL
# {http://www.plcopen.org/xml/tc6_0200}variable
# {http://www.plcopen.org/xml/tc6_0200}type
# {http://www.plcopen.org/xml/tc6_0200}BOOL
# {http://www.plcopen.org/xml/tc6_0200}variable
# {http://www.plcopen.org/xml/tc6_0200}type
# {http://www.plcopen.org/xml/tc6_0200}BOOL
# {http://www.plcopen.org/xml/tc6_0200}variable
# {http://www.plcopen.org/xml/tc6_0200}type
# {http://www.plcopen.org/xml/tc6_0200}BOOL
# {http://www.plcopen.org/xml/tc6_0200}variable
# {http://www.plcopen.org/xml/tc6_0200}type
# {http://www.plcopen.org/xml/tc6_0200}BOOL
# {http://www.plcopen.org/xml/tc6_0200}variable
# {http://www.plcopen.org/xml/tc6_0200}type
# {http://www.plcopen.org/xml/tc6_0200}BOOL
# {http://www.plcopen.org/xml/tc6_0200}variable
# {http://www.plcopen.org/xml/tc6_0200}type
# {http://www.plcopen.org/xml/tc6_0200}BOOL
# {http://www.plcopen.org/xml/tc6_0200}variable
# {http://www.plcopen.org/xml/tc6_0200}type
# {http://www.plcopen.org/xml/tc6_0200}BOOL
# {http://www.plcopen.org/xml/tc6_0200}variable
# {http://www.plcopen.org/xml/tc6_0200}type
# {http://www.plcopen.org/xml/tc6_0200}BOOL
# {http://www.plcopen.org/xml/tc6_0200}documentation
# {http://www.w3.org/1999/xhtml}xhtml
# {http://www.plcopen.org/xml/tc6_0200}variable
# {http://www.plcopen.org/xml/tc6_0200}type
# {http://www.plcopen.org/xml/tc6_0200}BOOL
# {http://www.plcopen.org/xml/tc6_0200}variable
# {http://www.plcopen.org/xml/tc6_0200}type
# {http://www.plcopen.org/xml/tc6_0200}BOOL
# {http://www.plcopen.org/xml/tc6_0200}variable
# {http://www.plcopen.org/xml/tc6_0200}type
# {http://www.plcopen.org/xml/tc6_0200}BOOL
# {http://www.plcopen.org/xml/tc6_0200}variable
# {http://www.plcopen.org/xml/tc6_0200}type
# {http://www.plcopen.org/xml/tc6_0200}BOOL
# {http://www.plcopen.org/xml/tc6_0200}variable
# {http://www.plcopen.org/xml/tc6_0200}type
# {http://www.plcopen.org/xml/tc6_0200}BOOL
# {http://www.plcopen.org/xml/tc6_0200}variable
# {http://www.plcopen.org/xml/tc6_0200}type
# {http://www.plcopen.org/xml/tc6_0200}BOOL
# {http://www.plcopen.org/xml/tc6_0200}variable
# {http://www.plcopen.org/xml/tc6_0200}type
# {http://www.plcopen.org/xml/tc6_0200}BOOL
# {http://www.plcopen.org/xml/tc6_0200}variable
# {http://www.plcopen.org/xml/tc6_0200}type
# {http://www.plcopen.org/xml/tc6_0200}BOOL
# {http://www.plcopen.org/xml/tc6_0200}documentation
# {http://www.w3.org/1999/xhtml}xhtml
# {http://www.plcopen.org/xml/tc6_0200}variable
# {http://www.plcopen.org/xml/tc6_0200}type
# {http://www.plcopen.org/xml/tc6_0200}BOOL
# {http://www.plcopen.org/xml/tc6_0200}variable
# {http://www.plcopen.org/xml/tc6_0200}type
# {http://www.plcopen.org/xml/tc6_0200}BOOL
# {http://www.plcopen.org/xml/tc6_0200}variable
# {http://www.plcopen.org/xml/tc6_0200}type
# {http://www.plcopen.org/xml/tc6_0200}BOOL
# {http://www.plcopen.org/xml/tc6_0200}variable
# {http://www.plcopen.org/xml/tc6_0200}type
# {http://www.plcopen.org/xml/tc6_0200}BOOL
# {http://www.plcopen.org/xml/tc6_0200}variable
# {http://www.plcopen.org/xml/tc6_0200}type
# {http://www.plcopen.org/xml/tc6_0200}BOOL
# {http://www.plcopen.org/xml/tc6_0200}variable
# {http://www.plcopen.org/xml/tc6_0200}type
# {http://www.plcopen.org/xml/tc6_0200}BOOL
# {http://www.plcopen.org/xml/tc6_0200}variable
# {http://www.plcopen.org/xml/tc6_0200}type
# {http://www.plcopen.org/xml/tc6_0200}BOOL
# {http://www.plcopen.org/xml/tc6_0200}variable
# {http://www.plcopen.org/xml/tc6_0200}type
# {http://www.plcopen.org/xml/tc6_0200}BOOL
# {http://www.plcopen.org/xml/tc6_0200}variable
# {http://www.plcopen.org/xml/tc6_0200}type
# {http://www.plcopen.org/xml/tc6_0200}BOOL
# {http://www.plcopen.org/xml/tc6_0200}variable
# {http://www.plcopen.org/xml/tc6_0200}type
# {http://www.plcopen.org/xml/tc6_0200}BOOL
# {http://www.plcopen.org/xml/tc6_0200}variable
# {http://www.plcopen.org/xml/tc6_0200}type
# {http://www.plcopen.org/xml/tc6_0200}BOOL
# {http://www.plcopen.org/xml/tc6_0200}documentation
# {http://www.w3.org/1999/xhtml}xhtml
# {http://www.plcopen.org/xml/tc6_0200}variable
# {http://www.plcopen.org/xml/tc6_0200}type
# {http://www.plcopen.org/xml/tc6_0200}BOOL
# {http://www.plcopen.org/xml/tc6_0200}variable
# {http://www.plcopen.org/xml/tc6_0200}type
# {http://www.plcopen.org/xml/tc6_0200}BOOL
# {http://www.plcopen.org/xml/tc6_0200}variable
# {http://www.plcopen.org/xml/tc6_0200}type
# {http://www.plcopen.org/xml/tc6_0200}BOOL
# {http://www.plcopen.org/xml/tc6_0200}variable
# {http://www.plcopen.org/xml/tc6_0200}type
# {http://www.plcopen.org/xml/tc6_0200}BOOL
# {http://www.plcopen.org/xml/tc6_0200}variable
# {http://www.plcopen.org/xml/tc6_0200}type
# {http://www.plcopen.org/xml/tc6_0200}BOOL
# {http://www.plcopen.org/xml/tc6_0200}variable
# {http://www.plcopen.org/xml/tc6_0200}type
# {http://www.plcopen.org/xml/tc6_0200}BOOL
# {http://www.plcopen.org/xml/tc6_0200}variable
# {http://www.plcopen.org/xml/tc6_0200}type
# {http://www.plcopen.org/xml/tc6_0200}BOOL
# {http://www.plcopen.org/xml/tc6_0200}variable
# {http://www.plcopen.org/xml/tc6_0200}type
# {http://www.plcopen.org/xml/tc6_0200}BOOL
# {http://www.plcopen.org/xml/tc6_0200}variable
# {http://www.plcopen.org/xml/tc6_0200}type
# {http://www.plcopen.org/xml/tc6_0200}BOOL
# {http://www.plcopen.org/xml/tc6_0200}variable
# {http://www.plcopen.org/xml/tc6_0200}type
# {http://www.plcopen.org/xml/tc6_0200}BOOL
# {http://www.plcopen.org/xml/tc6_0200}variable
# {http://www.plcopen.org/xml/tc6_0200}type
# {http://www.plcopen.org/xml/tc6_0200}BOOL
# {http://www.plcopen.org/xml/tc6_0200}documentation
# {http://www.w3.org/1999/xhtml}xhtml
# {http://www.plcopen.org/xml/tc6_0200}variable
# {http://www.plcopen.org/xml/tc6_0200}type
# {http://www.plcopen.org/xml/tc6_0200}BOOL
# {http://www.plcopen.org/xml/tc6_0200}variable
# {http://www.plcopen.org/xml/tc6_0200}type
# {http://www.plcopen.org/xml/tc6_0200}BOOL
# {http://www.plcopen.org/xml/tc6_0200}variable
# {http://www.plcopen.org/xml/tc6_0200}type
# {http://www.plcopen.org/xml/tc6_0200}BOOL
# {http://www.plcopen.org/xml/tc6_0200}variable
# {http://www.plcopen.org/xml/tc6_0200}type
# {http://www.plcopen.org/xml/tc6_0200}BOOL
# {http://www.plcopen.org/xml/tc6_0200}variable
# {http://www.plcopen.org/xml/tc6_0200}type
# {http://www.plcopen.org/xml/tc6_0200}BOOL
# {http://www.plcopen.org/xml/tc6_0200}variable
# {http://www.plcopen.org/xml/tc6_0200}type
# {http://www.plcopen.org/xml/tc6_0200}BOOL
# {http://www.plcopen.org/xml/tc6_0200}variable
# {http://www.plcopen.org/xml/tc6_0200}type
# {http://www.plcopen.org/xml/tc6_0200}BOOL
# {http://www.plcopen.org/xml/tc6_0200}variable
# {http://www.plcopen.org/xml/tc6_0200}type
# {http://www.plcopen.org/xml/tc6_0200}BOOL
# {http://www.plcopen.org/xml/tc6_0200}variable
# {http://www.plcopen.org/xml/tc6_0200}type
# {http://www.plcopen.org/xml/tc6_0200}BOOL
# {http://www.plcopen.org/xml/tc6_0200}variable
# {http://www.plcopen.org/xml/tc6_0200}type
# {http://www.plcopen.org/xml/tc6_0200}BOOL
# {http://www.plcopen.org/xml/tc6_0200}variable
# {http://www.plcopen.org/xml/tc6_0200}type
# {http://www.plcopen.org/xml/tc6_0200}BOOL
# {http://www.plcopen.org/xml/tc6_0200}variable
# {http://www.plcopen.org/xml/tc6_0200}type
# {http://www.plcopen.org/xml/tc6_0200}BOOL
# {http://www.plcopen.org/xml/tc6_0200}variable
# {http://www.plcopen.org/xml/tc6_0200}type
# {http://www.plcopen.org/xml/tc6_0200}BOOL
# {http://www.plcopen.org/xml/tc6_0200}variable
# {http://www.plcopen.org/xml/tc6_0200}type
# {http://www.plcopen.org/xml/tc6_0200}BOOL
# {http://www.plcopen.org/xml/tc6_0200}variable
# {http://www.plcopen.org/xml/tc6_0200}type
# {http://www.plcopen.org/xml/tc6_0200}BOOL
# {http://www.plcopen.org/xml/tc6_0200}variable
# {http://www.plcopen.org/xml/tc6_0200}type
# {http://www.plcopen.org/xml/tc6_0200}BOOL
# {http://www.plcopen.org/xml/tc6_0200}variable
# {http://www.plcopen.org/xml/tc6_0200}type
# {http://www.plcopen.org/xml/tc6_0200}BOOL
# {http://www.plcopen.org/xml/tc6_0200}variable
# {http://www.plcopen.org/xml/tc6_0200}type
# {http://www.plcopen.org/xml/tc6_0200}BOOL
# {http://www.plcopen.org/xml/tc6_0200}variable
# {http://www.plcopen.org/xml/tc6_0200}type
# {http://www.plcopen.org/xml/tc6_0200}BOOL
# {http://www.plcopen.org/xml/tc6_0200}variable
# {http://www.plcopen.org/xml/tc6_0200}type
# {http://www.plcopen.org/xml/tc6_0200}BOOL
# {http://www.plcopen.org/xml/tc6_0200}variable
# {http://www.plcopen.org/xml/tc6_0200}type
# {http://www.plcopen.org/xml/tc6_0200}BOOL
# {http://www.plcopen.org/xml/tc6_0200}variable
# {http://www.plcopen.org/xml/tc6_0200}type
# {http://www.plcopen.org/xml/tc6_0200}BOOL
# {http://www.plcopen.org/xml/tc6_0200}variable
# {http://www.plcopen.org/xml/tc6_0200}type
# {http://www.plcopen.org/xml/tc6_0200}BOOL
# {http://www.plcopen.org/xml/tc6_0200}variable
# {http://www.plcopen.org/xml/tc6_0200}type
# {http://www.plcopen.org/xml/tc6_0200}BOOL
# {http://www.plcopen.org/xml/tc6_0200}variable
# {http://www.plcopen.org/xml/tc6_0200}type
# {http://www.plcopen.org/xml/tc6_0200}BOOL
# {http://www.plcopen.org/xml/tc6_0200}variable
# {http://www.plcopen.org/xml/tc6_0200}type
# {http://www.plcopen.org/xml/tc6_0200}BOOL
# {http://www.plcopen.org/xml/tc6_0200}variable
# {http://www.plcopen.org/xml/tc6_0200}type
# {http://www.plcopen.org/xml/tc6_0200}BOOL
# {http://www.plcopen.org/xml/tc6_0200}documentation
# {http://www.w3.org/1999/xhtml}xhtml
# {http://www.plcopen.org/xml/tc6_0200}variable
# {http://www.plcopen.org/xml/tc6_0200}type
# {http://www.plcopen.org/xml/tc6_0200}BOOL
# {http://www.plcopen.org/xml/tc6_0200}variable
# {http://www.plcopen.org/xml/tc6_0200}type
# {http://www.plcopen.org/xml/tc6_0200}BOOL
# {http://www.plcopen.org/xml/tc6_0200}variable
# {http://www.plcopen.org/xml/tc6_0200}type
# {http://www.plcopen.org/xml/tc6_0200}BOOL
# {http://www.plcopen.org/xml/tc6_0200}variable
# {http://www.plcopen.org/xml/tc6_0200}type
# {http://www.plcopen.org/xml/tc6_0200}BOOL
# {http://www.plcopen.org/xml/tc6_0200}variable
# {http://www.plcopen.org/xml/tc6_0200}type
# {http://www.plcopen.org/xml/tc6_0200}BOOL
# {http://www.plcopen.org/xml/tc6_0200}variable
# {http://www.plcopen.org/xml/tc6_0200}type
# {http://www.plcopen.org/xml/tc6_0200}BOOL
# {http://www.plcopen.org/xml/tc6_0200}variable
# {http://www.plcopen.org/xml/tc6_0200}type
# {http://www.plcopen.org/xml/tc6_0200}BOOL
# {http://www.plcopen.org/xml/tc6_0200}variable
# {http://www.plcopen.org/xml/tc6_0200}type
# {http://www.plcopen.org/xml/tc6_0200}BOOL
# {http://www.plcopen.org/xml/tc6_0200}variable
# {http://www.plcopen.org/xml/tc6_0200}type
# {http://www.plcopen.org/xml/tc6_0200}BOOL
# {http://www.plcopen.org/xml/tc6_0200}variable
# {http://www.plcopen.org/xml/tc6_0200}type
# {http://www.plcopen.org/xml/tc6_0200}BOOL
# {http://www.plcopen.org/xml/tc6_0200}variable
# {http://www.plcopen.org/xml/tc6_0200}type
# {http://www.plcopen.org/xml/tc6_0200}BOOL
# {http://www.plcopen.org/xml/tc6_0200}globalVars
# {http://www.plcopen.org/xml/tc6_0200}variable
# {http://www.plcopen.org/xml/tc6_0200}type
# {http://www.plcopen.org/xml/tc6_0200}TIME
# {http://www.plcopen.org/xml/tc6_0200}variable
# {http://www.plcopen.org/xml/tc6_0200}type
# {http://www.plcopen.org/xml/tc6_0200}TIME
# {http://www.plcopen.org/xml/tc6_0200}variable
# {http://www.plcopen.org/xml/tc6_0200}type
# {http://www.plcopen.org/xml/tc6_0200}TIME
# {http://www.plcopen.org/xml/tc6_0200}variable
# {http://www.plcopen.org/xml/tc6_0200}type
# {http://www.plcopen.org/xml/tc6_0200}TIME
# {http://www.plcopen.org/xml/tc6_0200}variable
# {http://www.plcopen.org/xml/tc6_0200}type
# {http://www.plcopen.org/xml/tc6_0200}TIME
# {http://www.plcopen.org/xml/tc6_0200}variable
# {http://www.plcopen.org/xml/tc6_0200}type
# {http://www.plcopen.org/xml/tc6_0200}TIME
# {http://www.plcopen.org/xml/tc6_0200}variable
# {http://www.plcopen.org/xml/tc6_0200}type
# {http://www.plcopen.org/xml/tc6_0200}TIME
# {http://www.plcopen.org/xml/tc6_0200}variable
# {http://www.plcopen.org/xml/tc6_0200}type
# {http://www.plcopen.org/xml/tc6_0200}TIME
# {http://www.plcopen.org/xml/tc6_0200}variable
# {http://www.plcopen.org/xml/tc6_0200}type
# {http://www.plcopen.org/xml/tc6_0200}TIME
# {http://www.plcopen.org/xml/tc6_0200}variable
# {http://www.plcopen.org/xml/tc6_0200}type
# {http://www.plcopen.org/xml/tc6_0200}TIME
# {http://www.plcopen.org/xml/tc6_0200}variable
# {http://www.plcopen.org/xml/tc6_0200}type
# {http://www.plcopen.org/xml/tc6_0200}derived
# {http://www.plcopen.org/xml/tc6_0200}variable
# {http://www.plcopen.org/xml/tc6_0200}type
# {http://www.plcopen.org/xml/tc6_0200}derived
# {http://www.plcopen.org/xml/tc6_0200}variable
# {http://www.plcopen.org/xml/tc6_0200}type
# {http://www.plcopen.org/xml/tc6_0200}derived
# {http://www.plcopen.org/xml/tc6_0200}variable
# {http://www.plcopen.org/xml/tc6_0200}type
# {http://www.plcopen.org/xml/tc6_0200}derived
# {http://www.plcopen.org/xml/tc6_0200}variable
# {http://www.plcopen.org/xml/tc6_0200}type
# {http://www.plcopen.org/xml/tc6_0200}DINT
# {http://www.plcopen.org/xml/tc6_0200}variable
# {http://www.plcopen.org/xml/tc6_0200}type
# {http://www.plcopen.org/xml/tc6_0200}UDINT
# {http://www.plcopen.org/xml/tc6_0200}variable
# {http://www.plcopen.org/xml/tc6_0200}type
# {http://www.plcopen.org/xml/tc6_0200}UDINT
# {http://www.plcopen.org/xml/tc6_0200}variable
# {http://www.plcopen.org/xml/tc6_0200}type
# {http://www.plcopen.org/xml/tc6_0200}TIME
# {http://www.plcopen.org/xml/tc6_0200}documentation
# {http://www.w3.org/1999/xhtml}xhtml
# {http://www.plcopen.org/xml/tc6_0200}variable
# {http://www.plcopen.org/xml/tc6_0200}type
# {http://www.plcopen.org/xml/tc6_0200}TIME
# {http://www.plcopen.org/xml/tc6_0200}variable
# {http://www.plcopen.org/xml/tc6_0200}type
# {http://www.plcopen.org/xml/tc6_0200}TIME
# {http://www.plcopen.org/xml/tc6_0200}variable
# {http://www.plcopen.org/xml/tc6_0200}type
# {http://www.plcopen.org/xml/tc6_0200}TIME
# {http://www.plcopen.org/xml/tc6_0200}variable
# {http://www.plcopen.org/xml/tc6_0200}type
# {http://www.plcopen.org/xml/tc6_0200}TIME
# {http://www.plcopen.org/xml/tc6_0200}variable
# {http://www.plcopen.org/xml/tc6_0200}type
# {http://www.plcopen.org/xml/tc6_0200}TIME
# {http://www.plcopen.org/xml/tc6_0200}variable
# {http://www.plcopen.org/xml/tc6_0200}type
# {http://www.plcopen.org/xml/tc6_0200}TIME
# {http://www.plcopen.org/xml/tc6_0200}variable
# {http://www.plcopen.org/xml/tc6_0200}type
# ...
# {http://www.plcopen.org/xml/tc6_0200}connection
# {http://www.plcopen.org/xml/tc6_0200}variable
# {http://www.plcopen.org/xml/tc6_0200}connectionPointIn
# {http://www.plcopen.org/xml/tc6_0200}connection
# {http://www.plcopen.org/xml/tc6_0200}inOutVariables
# {http://www.plcopen.org/xml/tc6_0200}outputVariables
# {http://www.plcopen.org/xml/tc6_0200}variable
# {http://www.plcopen.org/xml/tc6_0200}connectionPointOut
# {http://www.plcopen.org/xml/tc6_0200}variable
# {http://www.plcopen.org/xml/tc6_0200}connectionPointOut
# {http://www.plcopen.org/xml/tc6_0200}expression
# {http://www.plcopen.org/xml/tc6_0200}addData
# {http://www.plcopen.org/xml/tc6_0200}data
# CallType
# {http://www.plcopen.org/xml/tc6_0200}inVariable
# {http://www.plcopen.org/xml/tc6_0200}position
# {http://www.plcopen.org/xml/tc6_0200}connectionPointOut
# {http://www.plcopen.org/xml/tc6_0200}expression
# {http://www.plcopen.org/xml/tc6_0200}inVariable
# {http://www.plcopen.org/xml/tc6_0200}position
# {http://www.plcopen.org/xml/tc6_0200}connectionPointOut
# {http://www.plcopen.org/xml/tc6_0200}expression
# {http://www.plcopen.org/xml/tc6_0200}block
# {http://www.plcopen.org/xml/tc6_0200}position
# {http://www.plcopen.org/xml/tc6_0200}inputVariables
# {http://www.plcopen.org/xml/tc6_0200}variable
# {http://www.plcopen.org/xml/tc6_0200}connectionPointIn
# {http://www.plcopen.org/xml/tc6_0200}connection
# {http://www.plcopen.org/xml/tc6_0200}variable
# {http://www.plcopen.org/xml/tc6_0200}connectionPointIn
# {http://www.plcopen.org/xml/tc6_0200}connection
# {http://www.plcopen.org/xml/tc6_0200}variable
# {http://www.plcopen.org/xml/tc6_0200}connectionPointIn
# {http://www.plcopen.org/xml/tc6_0200}connection
# {http://www.plcopen.org/xml/tc6_0200}inOutVariables
# {http://www.plcopen.org/xml/tc6_0200}outputVariables
# {http://www.plcopen.org/xml/tc6_0200}variable
# {http://www.plcopen.org/xml/tc6_0200}connectionPointOut
# {http://www.plcopen.org/xml/tc6_0200}variable
# {http://www.plcopen.org/xml/tc6_0200}connectionPointOut
# {http://www.plcopen.org/xml/tc6_0200}expression
# {http://www.plcopen.org/xml/tc6_0200}addData
# {http://www.plcopen.org/xml/tc6_0200}data
# CallType
# {http://www.plcopen.org/xml/tc6_0200}inVariable
# {http://www.plcopen.org/xml/tc6_0200}position
# {http://www.plcopen.org/xml/tc6_0200}connectionPointOut
# {http://www.plcopen.org/xml/tc6_0200}expression
# {http://www.plcopen.org/xml/tc6_0200}inVariable
# {http://www.plcopen.org/xml/tc6_0200}position
# {http://www.plcopen.org/xml/tc6_0200}connectionPointOut
# {http://www.plcopen.org/xml/tc6_0200}expression
# {http://www.plcopen.org/xml/tc6_0200}block
# {http://www.plcopen.org/xml/tc6_0200}position
# {http://www.plcopen.org/xml/tc6_0200}inputVariables
# {http://www.plcopen.org/xml/tc6_0200}variable
# {http://www.plcopen.org/xml/tc6_0200}connectionPointIn
# {http://www.plcopen.org/xml/tc6_0200}connection
# {http://www.plcopen.org/xml/tc6_0200}variable
# {http://www.plcopen.org/xml/tc6_0200}connectionPointIn
# {http://www.plcopen.org/xml/tc6_0200}connection
# {http://www.plcopen.org/xml/tc6_0200}variable
# {http://www.plcopen.org/xml/tc6_0200}connectionPointIn
# {http://www.plcopen.org/xml/tc6_0200}connection
# {http://www.plcopen.org/xml/tc6_0200}inOutVariables
# {http://www.plcopen.org/xml/tc6_0200}outputVariables
# {http://www.plcopen.org/xml/tc6_0200}variable
# {http://www.plcopen.org/xml/tc6_0200}connectionPointOut
# {http://www.plcopen.org/xml/tc6_0200}variable
# {http://www.plcopen.org/xml/tc6_0200}connectionPointOut
# {http://www.plcopen.org/xml/tc6_0200}expression
# {http://www.plcopen.org/xml/tc6_0200}addData
# {http://www.plcopen.org/xml/tc6_0200}data
# CallType
# {http://www.plcopen.org/xml/tc6_0200}inVariable
# {http://www.plcopen.org/xml/tc6_0200}position
# {http://www.plcopen.org/xml/tc6_0200}connectionPointOut
# {http://www.plcopen.org/xml/tc6_0200}expression
# {http://www.plcopen.org/xml/tc6_0200}inVariable
# {http://www.plcopen.org/xml/tc6_0200}position
# {http://www.plcopen.org/xml/tc6_0200}connectionPointOut
# {http://www.plcopen.org/xml/tc6_0200}expression
# {http://www.plcopen.org/xml/tc6_0200}block
# {http://www.plcopen.org/xml/tc6_0200}position
# {http://www.plcopen.org/xml/tc6_0200}inputVariables
# {http://www.plcopen.org/xml/tc6_0200}variable
# {http://www.plcopen.org/xml/tc6_0200}connectionPointIn
# {http://www.plcopen.org/xml/tc6_0200}connection
# {http://www.plcopen.org/xml/tc6_0200}variable
# {http://www.plcopen.org/xml/tc6_0200}connectionPointIn
# {http://www.plcopen.org/xml/tc6_0200}connection
# {http://www.plcopen.org/xml/tc6_0200}variable
# {http://www.plcopen.org/xml/tc6_0200}connectionPointIn
# {http://www.plcopen.org/xml/tc6_0200}connection
# {http://www.plcopen.org/xml/tc6_0200}inOutVariables
# {http://www.plcopen.org/xml/tc6_0200}outputVariables
# {http://www.plcopen.org/xml/tc6_0200}variable
# {http://www.plcopen.org/xml/tc6_0200}connectionPointOut
# {http://www.plcopen.org/xml/tc6_0200}variable
# {http://www.plcopen.org/xml/tc6_0200}connectionPointOut
# {http://www.plcopen.org/xml/tc6_0200}expression
# {http://www.plcopen.org/xml/tc6_0200}addData
# {http://www.plcopen.org/xml/tc6_0200}data
# CallType
# {http://www.plcopen.org/xml/tc6_0200}inVariable
# {http://www.plcopen.org/xml/tc6_0200}position
# {http://www.plcopen.org/xml/tc6_0200}connectionPointOut
# {http://www.plcopen.org/xml/tc6_0200}expression
# {http://www.plcopen.org/xml/tc6_0200}inVariable
# {http://www.plcopen.org/xml/tc6_0200}position
# {http://www.plcopen.org/xml/tc6_0200}connectionPointOut
# {http://www.plcopen.org/xml/tc6_0200}expression
# {http://www.plcopen.org/xml/tc6_0200}block
# {http://www.plcopen.org/xml/tc6_0200}position
# {http://www.plcopen.org/xml/tc6_0200}inputVariables
# {http://www.plcopen.org/xml/tc6_0200}variable
# {http://www.plcopen.org/xml/tc6_0200}connectionPointIn
# {http://www.plcopen.org/xml/tc6_0200}connection
# {http://www.plcopen.org/xml/tc6_0200}variable
# {http://www.plcopen.org/xml/tc6_0200}connectionPointIn
# {http://www.plcopen.org/xml/tc6_0200}connection
# {http://www.plcopen.org/xml/tc6_0200}variable
# {http://www.plcopen.org/xml/tc6_0200}connectionPointIn
# {http://www.plcopen.org/xml/tc6_0200}connection
# {http://www.plcopen.org/xml/tc6_0200}inOutVariables
# {http://www.plcopen.org/xml/tc6_0200}outputVariables
# {http://www.plcopen.org/xml/tc6_0200}variable
# {http://www.plcopen.org/xml/tc6_0200}connectionPointOut
# {http://www.plcopen.org/xml/tc6_0200}variable
# {http://www.plcopen.org/xml/tc6_0200}connectionPointOut
# {http://www.plcopen.org/xml/tc6_0200}expression
# {http://www.plcopen.org/xml/tc6_0200}addData
# {http://www.plcopen.org/xml/tc6_0200}data
# CallType
# {http://www.plcopen.org/xml/tc6_0200}inVariable
# {http://www.plcopen.org/xml/tc6_0200}position
# {http://www.plcopen.org/xml/tc6_0200}connectionPointOut
# {http://www.plcopen.org/xml/tc6_0200}expression
# {http://www.plcopen.org/xml/tc6_0200}inVariable
# {http://www.plcopen.org/xml/tc6_0200}position
# {http://www.plcopen.org/xml/tc6_0200}connectionPointOut
# {http://www.plcopen.org/xml/tc6_0200}expression
# {http://www.plcopen.org/xml/tc6_0200}block
# {http://www.plcopen.org/xml/tc6_0200}position
# {http://www.plcopen.org/xml/tc6_0200}inputVariables
# {http://www.plcopen.org/xml/tc6_0200}variable
# {http://www.plcopen.org/xml/tc6_0200}connectionPointIn
# {http://www.plcopen.org/xml/tc6_0200}connection
# {http://www.plcopen.org/xml/tc6_0200}variable
# {http://www.plcopen.org/xml/tc6_0200}connectionPointIn
# {http://www.plcopen.org/xml/tc6_0200}connection
# {http://www.plcopen.org/xml/tc6_0200}variable
# {http://www.plcopen.org/xml/tc6_0200}connectionPointIn
# {http://www.plcopen.org/xml/tc6_0200}connection
# {http://www.plcopen.org/xml/tc6_0200}inOutVariables
# {http://www.plcopen.org/xml/tc6_0200}outputVariables
# {http://www.plcopen.org/xml/tc6_0200}variable
# {http://www.plcopen.org/xml/tc6_0200}connectionPointOut
# {http://www.plcopen.org/xml/tc6_0200}variable
# {http://www.plcopen.org/xml/tc6_0200}connectionPointOut
# {http://www.plcopen.org/xml/tc6_0200}expression
# {http://www.plcopen.org/xml/tc6_0200}addData
# {http://www.plcopen.org/xml/tc6_0200}data
# CallType
# {http://www.plcopen.org/xml/tc6_0200}inVariable
# {http://www.plcopen.org/xml/tc6_0200}position
# {http://www.plcopen.org/xml/tc6_0200}connectionPointOut
# {http://www.plcopen.org/xml/tc6_0200}expression
# {http://www.plcopen.org/xml/tc6_0200}inVariable
# {http://www.plcopen.org/xml/tc6_0200}position
# {http://www.plcopen.org/xml/tc6_0200}connectionPointOut
# {http://www.plcopen.org/xml/tc6_0200}expression
# {http://www.plcopen.org/xml/tc6_0200}block
# {http://www.plcopen.org/xml/tc6_0200}position
# {http://www.plcopen.org/xml/tc6_0200}inputVariables
# {http://www.plcopen.org/xml/tc6_0200}variable
# {http://www.plcopen.org/xml/tc6_0200}connectionPointIn
# {http://www.plcopen.org/xml/tc6_0200}connection
# {http://www.plcopen.org/xml/tc6_0200}variable
# {http://www.plcopen.org/xml/tc6_0200}connectionPointIn
# {http://www.plcopen.org/xml/tc6_0200}connection
# {http://www.plcopen.org/xml/tc6_0200}variable
# {http://www.plcopen.org/xml/tc6_0200}connectionPointIn
# {http://www.plcopen.org/xml/tc6_0200}connection
# {http://www.plcopen.org/xml/tc6_0200}inOutVariables
# {http://www.plcopen.org/xml/tc6_0200}outputVariables
# {http://www.plcopen.org/xml/tc6_0200}variable
# {http://www.plcopen.org/xml/tc6_0200}connectionPointOut
# {http://www.plcopen.org/xml/tc6_0200}variable
# {http://www.plcopen.org/xml/tc6_0200}connectionPointOut
# {http://www.plcopen.org/xml/tc6_0200}expression
# {http://www.plcopen.org/xml/tc6_0200}addData
# {http://www.plcopen.org/xml/tc6_0200}data
# CallType
# {http://www.plcopen.org/xml/tc6_0200}vendorElement
# {http://www.plcopen.org/xml/tc6_0200}position
# {http://www.plcopen.org/xml/tc6_0200}alternativeText
# {http://www.w3.org/1999/xhtml}xhtml
# {http://www.plcopen.org/xml/tc6_0200}addData
# {http://www.plcopen.org/xml/tc6_0200}data
# ParallelBranch
# BranchInput
# connectionPointIn
# connection
# BranchTrees
# Tree
# connectionPointIn
# connection
# Tree
# connectionPointIn
# connection
# Tree
# connectionPointIn
# connection
# Tree
# connectionPointIn
# connection
# {http://www.plcopen.org/xml/tc6_0200}comment
# {http://www.plcopen.org/xml/tc6_0200}position
# {http://www.plcopen.org/xml/tc6_0200}content
# {http://www.w3.org/1999/xhtml}xhtml
# {http://www.plcopen.org/xml/tc6_0200}vendorElement
# {http://www.plcopen.org/xml/tc6_0200}position
# {http://www.plcopen.org/xml/tc6_0200}alternativeText
# {http://www.w3.org/1999/xhtml}xhtml
# {http://www.plcopen.org/xml/tc6_0200}addData
# {http://www.plcopen.org/xml/tc6_0200}data
# ElementType
# {http://www.plcopen.org/xml/tc6_0200}contact
# {http://www.plcopen.org/xml/tc6_0200}position
# {http://www.plcopen.org/xml/tc6_0200}connectionPointIn
# {http://www.plcopen.org/xml/tc6_0200}connection
# {http://www.plcopen.org/xml/tc6_0200}connectionPointOut
# {http://www.plcopen.org/xml/tc6_0200}variable
# {http://www.plcopen.org/xml/tc6_0200}contact
# {http://www.plcopen.org/xml/tc6_0200}position
# {http://www.plcopen.org/xml/tc6_0200}connectionPointIn
# {http://www.plcopen.org/xml/tc6_0200}connection
# {http://www.plcopen.org/xml/tc6_0200}connectionPointOut
# {http://www.plcopen.org/xml/tc6_0200}variable
# {http://www.plcopen.org/xml/tc6_0200}inVariable
# {http://www.plcopen.org/xml/tc6_0200}position
# {http://www.plcopen.org/xml/tc6_0200}connectionPointOut
# {http://www.plcopen.org/xml/tc6_0200}expression
# {http://www.plcopen.org/xml/tc6_0200}inVariable
# {http://www.plcopen.org/xml/tc6_0200}position
# {http://www.plcopen.org/xml/tc6_0200}connectionPointOut
# {http://www.plcopen.org/xml/tc6_0200}expression
# {http://www.plcopen.org/xml/tc6_0200}block
# {http://www.plcopen.org/xml/tc6_0200}position
# {http://www.plcopen.org/xml/tc6_0200}inputVariables
# {http://www.plcopen.org/xml/tc6_0200}variable
# {http://www.plcopen.org/xml/tc6_0200}connectionPointIn
# {http://www.plcopen.org/xml/tc6_0200}connection
# {http://www.plcopen.org/xml/tc6_0200}variable
# {http://www.plcopen.org/xml/tc6_0200}connectionPointIn
# {http://www.plcopen.org/xml/tc6_0200}connection
# {http://www.plcopen.org/xml/tc6_0200}variable
# {http://www.plcopen.org/xml/tc6_0200}connectionPointIn
# {http://www.plcopen.org/xml/tc6_0200}connection
# {http://www.plcopen.org/xml/tc6_0200}inOutVariables
# {http://www.plcopen.org/xml/tc6_0200}outputVariables
# {http://www.plcopen.org/xml/tc6_0200}variable
# {http://www.plcopen.org/xml/tc6_0200}connectionPointOut
# {http://www.plcopen.org/xml/tc6_0200}addData
# {http://www.plcopen.org/xml/tc6_0200}data
# CallType
# {http://www.plcopen.org/xml/tc6_0200}vendorElement
# {http://www.plcopen.org/xml/tc6_0200}position
# {http://www.plcopen.org/xml/tc6_0200}alternativeText
# {http://www.w3.org/1999/xhtml}xhtml
# {http://www.plcopen.org/xml/tc6_0200}addData
# {http://www.plcopen.org/xml/tc6_0200}data
# ParallelBranch
# BranchInput
# connectionPointIn
# connection
# BranchTrees
# Tree
# connectionPointIn
# connection
# Tree
# connectionPointIn
# connection
# {http://www.plcopen.org/xml/tc6_0200}inVariable
# {http://www.plcopen.org/xml/tc6_0200}position
# {http://www.plcopen.org/xml/tc6_0200}connectionPointOut
# {http://www.plcopen.org/xml/tc6_0200}expression
# {http://www.plcopen.org/xml/tc6_0200}block
# {http://www.plcopen.org/xml/tc6_0200}position
# {http://www.plcopen.org/xml/tc6_0200}inputVariables
# {http://www.plcopen.org/xml/tc6_0200}variable
# {http://www.plcopen.org/xml/tc6_0200}connectionPointIn
# {http://www.plcopen.org/xml/tc6_0200}connection
# {http://www.plcopen.org/xml/tc6_0200}connection
# {http://www.plcopen.org/xml/tc6_0200}variable
# {http://www.plcopen.org/xml/tc6_0200}connectionPointIn
# {http://www.plcopen.org/xml/tc6_0200}connection
# {http://www.plcopen.org/xml/tc6_0200}inOutVariables
# {http://www.plcopen.org/xml/tc6_0200}outputVariables
# {http://www.plcopen.org/xml/tc6_0200}variable
# {http://www.plcopen.org/xml/tc6_0200}connectionPointOut
# {http://www.plcopen.org/xml/tc6_0200}variable
# {http://www.plcopen.org/xml/tc6_0200}connectionPointOut
# {http://www.plcopen.org/xml/tc6_0200}expression
# {http://www.plcopen.org/xml/tc6_0200}addData
# {http://www.plcopen.org/xml/tc6_0200}data
# CallType
# {http://www.plcopen.org/xml/tc6_0200}rightPowerRail
# {http://www.plcopen.org/xml/tc6_0200}position
# {http://www.plcopen.org/xml/tc6_0200}connectionPointIn
# {http://www.plcopen.org/xml/tc6_0200}connection
# {http://www.plcopen.org/xml/tc6_0200}addData
# {http://www.plcopen.org/xml/tc6_0200}data
# BranchId
# {http://www.plcopen.org/xml/tc6_0200}connection
# {http://www.plcopen.org/xml/tc6_0200}addData
# {http://www.plcopen.org/xml/tc6_0200}data
# BranchId
# {http://www.plcopen.org/xml/tc6_0200}connection
# {http://www.plcopen.org/xml/tc6_0200}addData
# {http://www.plcopen.org/xml/tc6_0200}data
# BranchId
# {http://www.plcopen.org/xml/tc6_0200}connection
# {http://www.plcopen.org/xml/tc6_0200}addData
# {http://www.plcopen.org/xml/tc6_0200}data
# BranchId
# {http://www.plcopen.org/xml/tc6_0200}connection
# {http://www.plcopen.org/xml/tc6_0200}addData
# {http://www.plcopen.org/xml/tc6_0200}data
# BranchId
# {http://www.plcopen.org/xml/tc6_0200}connection
# {http://www.plcopen.org/xml/tc6_0200}addData
# {http://www.plcopen.org/xml/tc6_0200}data
# BranchId
# {http://www.plcopen.org/xml/tc6_0200}addData
# {http://www.plcopen.org/xml/tc6_0200}data
# {http://www.plcopen.org/xml/tc6_0200}Libraries
# {http://www.plcopen.org/xml/tc6_0200}Library
# {http://www.plcopen.org/xml/tc6_0200}Library
# {http://www.plcopen.org/xml/tc6_0200}Library
# {http://www.plcopen.org/xml/tc6_0200}Library
# {http://www.plcopen.org/xml/tc6_0200}Library
# {http://www.plcopen.org/xml/tc6_0200}Library
# {http://www.plcopen.org/xml/tc6_0200}Library
# {http://www.plcopen.org/xml/tc6_0200}Library
# {http://www.plcopen.org/xml/tc6_0200}Library
# {http://www.plcopen.org/xml/tc6_0200}Library
# {http://www.plcopen.org/xml/tc6_0200}Library
# {http://www.plcopen.org/xml/tc6_0200}Parameters
# {http://www.plcopen.org/xml/tc6_0200}Parameter
# {http://www.plcopen.org/xml/tc6_0200}Parameter
# {http://www.plcopen.org/xml/tc6_0200}Library
# {http://www.plcopen.org/xml/tc6_0200}Library
# {http://www.plcopen.org/xml/tc6_0200}Library
# {http://www.plcopen.org/xml/tc6_0200}Library
# {http://www.plcopen.org/xml/tc6_0200}Library
# {http://www.plcopen.org/xml/tc6_0200}Library
# {http://www.plcopen.org/xml/tc6_0200}Library
# {http://www.plcopen.org/xml/tc6_0200}Library
# {http://www.plcopen.org/xml/tc6_0200}Library
# {http://www.plcopen.org/xml/tc6_0200}Library
# {http://www.plcopen.org/xml/tc6_0200}addData
# No <contact> elements with edge attribute not 'none' were found.
